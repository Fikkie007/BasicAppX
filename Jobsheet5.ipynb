# %% [markdown]
# <a href="https://colab.research.google.com/github/Fikkie007/BasicAppX/blob/master/Jobsheet5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img_f = cv.imread('/content/drive/MyDrive/images/bottle.jpg')
img_rgb = cv.cvtColor(img_f, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
print(' Gamma Correction pada citra ')
print(' --------------------------- ')
try:
  gamma = int(input(' Masukkan Nilai Gamma: '))
except ValueError:
  print(' Error, not a number ')

original = cv.cvtColor(img_rgb, cv.COLOR_BGR2RGB)
gamma_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_image[y,x,c] = np.clip(255 * pow(original[y,x,c] / 255. (1 / gamma)), 0, 255)

final_frame = cv.hconcat((original, gamma_image))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
#  ---------------------------
#  Masukkan Nilai Gamma: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-a212e04b7c0c> in <module>()
#      12   for x in range(original.shape[1]):
#      13     for c in range(original.shape[2]):
# ---> 14       gamma_image[y,x,c] = np.clip(255 * pow(original[y,x,c] / 255. (1 / gamma)),0,255)
#      15
#      16 final_frame = cv.hconcat((original, gamma_image))
#
# TypeError: 'float' object is not callable
