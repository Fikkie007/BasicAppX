# %% [markdown]
# <a href="https://colab.research.google.com/github/Fikkie007/BasicAppX/blob/master/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np


print("Mengubah tingkat kecerahan citra")
print("--------------------------------")
try:
  brightness = int(input("Masukkan nulai kecerahan: "))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/images/bottle.jpg')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] * brightness, 0, 255)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukkan nulai kecerahan: 10
# <PIL.Image.Image image mode=RGB size=1280x416 at 0x7FD4BC2A8E10>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np


print("Mengubah kontras dan tingkat kecerahan citra")
print("--------------------------------")
try:
  brightness = int(input("Masukkan nulai kecerahan: "))
except ValueError:
  print('Error, not a number')

try:
  kontras = float(input("Masukkan kontras [1.0 - 3.0 ] :"))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/images/bottle.jpg')
brightness_image = np.zeros(original.shape, original.dtype)
kontras_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] * brightness, 0, 255)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      kontras_image[y,x,c] = np.clip(original * (259 * (kontras + 255)) / (255 * (259 - kontras)))

final_frame = cv.hconcat((original, brightness_image, kontras_image))
cv2_imshow(final_frame)
# Out:
# Mengubah kontras dan tingkat kecerahan citra
# --------------------------------
# Masukkan nulai kecerahan: 1
# Masukkan kontras [1.0 - 3.0 ] :1.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-2d6117fe6d89> in <module>()
#      28   for x in range(original.shape[1]):
#      29     for c in range(original.shape[2]):
# ---> 30       kontras_image[y,x,c] = np.clip(original * (259 * (kontras + 255)) / (255 * (259 - kontras)))
#      31
#      32 final_frame = cv.hconcat((original, brightness_image, kontras_image))
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# TypeError: _clip_dispatcher() missing 2 required positional arguments: 'a_min' and 'a_max'
